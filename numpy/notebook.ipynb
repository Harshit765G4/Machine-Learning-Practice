# %% [markdown]
# <!--
#
# Notebooks - A notebook is a special file (usually .ipynb) that lets us:
# - write code
# - run code
# - see output
# - Add notes, equations, images, charts - all in one place.
#
#
# Now one of the most popular notebooks are jupyter notebook and now lets see how we can download this using anaconda.
#
# and get a brief overview how it works and how it can be used in vs code and other platforms aswell.
#
# -->

# %% [markdown]
# <!-- Importing Numpy -->

# %%
import numpy as np

# %% [markdown]
# <!-- Basic Array Creation -->

# %%
arr = np.array([1,2,3,4])
arr

# %%
a = [1,2,3.5]
a
# Out:
# [1, 2, 3.5]

# %%
np.array(a) #convert every value of a into float datatype
# Out:
# array([1. , 2. , 3.5])
